# %%
import configparser
import networkx as nx
import itertools
import math
import random
import json
from tqdm import tqdm
import sys
import time
import timeit
import numpy as np

# %%
config = configparser.ConfigParser()
config.read("paths.cfg")
# Out:
# ['paths.cfg']

# %%
cpnet = None
cpnet_simple = None
concept2id = None
relation2id = None
id2relation = None
id2concept = None

# %%
def load_resources():
    global concept2id, relation2id, id2relation, id2concept
    concept2id = {}
    id2concept = {}
    with open(config["paths"]["concept_vocab"], "r", encoding="utf8") as f:
        for w in f.readlines():
            concept2id[w.strip()] = len(concept2id)
            id2concept[len(id2concept)] = w.strip()

    print("concept2id done")
    id2relation = {}
    relation2id = {}
    with open(config["paths"]["relation_vocab"], "r", encoding="utf8") as f:
        for w in f.readlines():
            id2relation[len(id2relation)] = w.strip()
            relation2id[w.strip()] = len(relation2id)
    print("relation2id done")

# %%
def load_cpnet():
    global cpnet,concept2id, relation2id, id2relation, id2concept, cpnet_simple
    print("loading cpnet....")
    cpnet = nx.read_gpickle(config["paths"]["conceptnet_en_graph"])
    print("Done")

    cpnet_simple = nx.Graph()
    for u, v, data in cpnet.edges(data=True):
        w = data['weight'] if 'weight' in data else 1.0
        if cpnet_simple.has_edge(u, v):
            cpnet_simple[u][v]['weight'] += w
        else:
            cpnet_simple.add_edge(u, v, weight=w)

# %%
def get_edge(src_concept, tgt_concept):
    global cpnet, concept2id, relation2id, id2relation, id2concept
    rel_list = cpnet[src_concept][tgt_concept]
    # tmp = [rel_list[item]["weight"] for item in rel_list]
    # s = tmp.index(min(tmp))
    # rel = rel_list[s]["rel"]
    return list(set([rel_list[item]["rel"] for item in rel_list]))

# %%
def find_paths(source, target, ifprint = False):
    global cpnet, concept2id, relation2id, id2relation, id2concept, cpnet_simple
    s = concept2id[source]
    t = concept2id[target]

    # try:
    #     lenth, path = nx.bidirectional_dijkstra(cpnet, source=s, target=t, weight="weight")
    #     # print(lenth)
    #     print(path)
    # except nx.NetworkXNoPath:
    #     print("no path")
    # paths = [path]

    if s not in cpnet_simple.nodes() or t not in cpnet_simple.nodes():
        return
    # paths =
    all_path = []
    all_path_set = set()

    for max_len in range(1, 5):
        for p in nx.all_simple_paths(cpnet_simple, source=s, target=t, cutoff=max_len):
            path_str = "-".join([str(c) for c in p])
            if path_str not in all_path_set:
                all_path_set.add(path_str)
                all_path.append(p)
            if len(all_path) >= 100:  # top shortest 300 paths
                break
        if len(all_path) >= 100:  # top shortest 300 paths
            break

    # all_path = [[int(c) for c in p.split("-")] for p in list(set(["-".join([str(c) for c in p]) for p in all_path]))]
    # print(len(all_path))
    all_path.sort(key=len, reverse=False)
    pf_res = []
    for p in all_path:
        # print([id2concept[i] for i in p])
        rl = []
        for src in range(len(p) - 1):
            src_concept = p[src]
            tgt_concept = p[src + 1]

            rel_list = get_edge(src_concept, tgt_concept)
            rl.append(rel_list)
            if ifprint:
                rel_list_str = []
                for rel in rel_list:
                    if rel < len(id2relation):
                        rel_list_str.append(id2relation[rel])
                    else:
                        rel_list_str.append(id2relation[rel - len(id2relation)]+"*")
                print(id2concept[src_concept], "----[%s]---> " %("/".join(rel_list_str)), end="")
                if src + 1 == len(p) - 1:
                    print(id2concept[tgt_concept], end="")
        if ifprint:
            print()

        pf_res.append({"path": p, "rel": rl})
    return pf_res

# %%
def process(filename, batch_id=-1):
    pf = []
    output_path = filename + ".%d" % (batch_id) + ".pf"
    import os
    if os.path.exists(output_path):
        print(output_path + " exists. Skip!")
        return

    load_resources()
    load_cpnet()
    with open(filename, 'r') as fp:
        mcp_data = json.load(fp)
        mcp_data = list(np.array_split(mcp_data, 100)[batch_id])

        for item in tqdm(mcp_data, desc="batch_id: %d "%batch_id):
            acs = item["ac"]
            qcs = item["qc"]
            pfr_qa = []  # path finding results
            for ac in acs:
                for qc in qcs:
                    pf_res = find_paths(qc, ac)
                    pfr_qa.append({"ac":ac, "qc":qc, "pf_res":pf_res})
            pf.append(pfr_qa)

    with open(output_path, 'w') as fi:
        json.dump(pf, fi)

# %%
load_resources()
load_cpnet()
# Out:
# concept2id done
# relation2id done
# loading cpnet....
# Done

# %%
find_paths("fill", "fountain_pen", ifprint=True)
print("--------")
# Out:
# fill ----[relatedto*]---> air ----[atlocation]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> water ----[atlocation]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> water ----[relatedto*/atlocation*/capableof/relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> water ----[relatedto*]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto*]---> apply ----[relatedto*]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto*]---> apply ----[relatedto*]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto*]---> art ----[relatedto*]---> calligraphy ----[usedfor*]---> fountain_pen
# fill ----[relatedto]---> top ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> put ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto*]---> clutter ----[atlocation]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> contents ----[atlocation]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> bucket ----[isa/relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> containers ----[relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> overflow ----[relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> pack ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> station ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> tank ----[isa]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> tooth ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto*]---> lead ----[relatedto]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto*]---> pod ----[isa]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto*]---> stuff ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto*]---> stuff ----[relatedto*]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto*]---> stuff ----[relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto*]---> stopper ----[relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[usedfor*]---> cavity ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[isa]---> event ----[relatedto*]---> blotter ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto]---> device ----[relatedto*]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto]---> key ----[atlocation]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto]---> keyboard ----[atlocation]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto]---> part ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> apply ----[relatedto*]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> apply ----[relatedto*]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*/relatedto]---> case ----[relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*/relatedto]---> case ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> change ----[atlocation]---> drawer ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> change ----[relatedto*/atlocation/relatedto]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> character ----[relatedto*]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> close ----[antonym]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> cover ----[relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> cover ----[relatedto*]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> cry ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> debt ----[relatedto]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> draw ----[relatedto]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> draw ----[relatedto*]---> drawer ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> drink ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> drop ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> feeble ----[relatedto*]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> go ----[relatedto]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> land ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> lead ----[relatedto]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> organization ----[usedfor*]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> organization ----[usedfor*]---> drawer ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> organize ----[relatedto]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> paint ----[relatedto*/relatedto]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> paint ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> play ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> point ----[relatedto]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> point ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> practice ----[relatedto*]---> calligraphy ----[usedfor*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> press ----[relatedto]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> print ----[relatedto]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> push ----[relatedto*]---> drawer ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> put ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> reading ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> return ----[relatedto]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> ring ----[atlocation]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> sail ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> sale ----[relatedto*]---> nib ----[relatedto*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> shock ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> sit ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> slip ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> stick ----[relatedto*]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> strength ----[relatedto*]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> studying ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> swim ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> tap ----[relatedto*]---> drawer ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> tap ----[relatedto]---> clicking ----[usedfor*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> twist ----[relatedto]---> twirling ----[usedfor*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> type ----[relatedto*]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> wash ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> watch ----[relatedto]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> wave ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> work ----[relatedto*/atlocation/usedfor*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> write ----[relatedto*/relatedto/hassubevent]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> write ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> writing ----[relatedto*/relatedto]---> calligraphy ----[usedfor*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> writing ----[relatedto*/usedfor*/relatedto/hassubevent]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> writing ----[relatedto*/usedfor*/relatedto]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> writing ----[relatedto*]---> brush_pen ----[relatedto]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto*]---> writing ----[relatedto*/relatedto]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto]---> action ----[relatedto]---> brush ----[relatedto]---> pen ----[isa*]---> fountain_pen
# fill ----[relatedto*]---> air ----[antonym/antonym*]---> fire ----[antonym]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto*]---> air ----[antonym/antonym*]---> land ----[relatedto*]---> pocket ----[atlocation*]---> fountain_pen
# fill ----[relatedto*]---> air ----[antonym/relatedto]---> vacuum ----[atlocation]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto*]---> air ----[antonym/antonym*/relatedto*]---> water ----[atlocation]---> container ----[isa*]---> fountain_pen
# fill ----[relatedto*]---> air ----[antonym/antonym*/relatedto*]---> water ----[relatedto*/atlocation*/capableof/relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto*]---> air ----[antonym/antonym*/relatedto*]---> water ----[relatedto*]---> ink ----[partof/atlocation]---> fountain_pen
# fill ----[relatedto*]---> air ----[relatedto*/antonym*/relatedto]---> space ----[relatedto*]---> desk ----[atlocation*]---> fountain_pen
# fill ----[relatedto*]---> air ----[relatedto*/antonym*]---> steam ----[relatedto]---> wet ----[relatedto]---> fountain_pen
# fill ----[relatedto*]---> air ----[atlocation]---> cupboard ----[atlocation*]---> container ----[isa*]---> fountain_pen
# --------

# %%
#
# find_paths("write", "fountain_pen", ifprint=True)
# print("--------")
# find_paths("write", "pen", ifprint=True)
find_paths("bottle", "liquor", ifprint=True)

print();print();print();print();print();


find_paths("cashier", "store", ifprint=True)
